# %%
from ase.io import read,Trajectory
from ase.neighborlist import natural_cutoffs, NeighborList
import torch
import numpy as np
from pathlib import Path

# %%
traj = Trajectory('simulation_300K.traj')
atoms = traj[0]
NL = NeighborList(natural_cutoffs(atoms), self_interaction=False)
NL.update(atoms)
bonds = NL.get_connectivity_matrix().todense().nonzero()
bonds = torch.tensor(bonds)
bonds.shape
# Out:
# torch.Size([2, 169])

# %%
print(atoms)
# Out:
# Atoms(symbols='H24Ca8O44Si12', pbc=True, cell=[[6.8037, 0.0, 0.0], [-4.139012893, 6.184814974, 0.0], [0.294028686, -0.269817895, 22.405446357]], momenta=..., calculator=SinglePointCalculator(...))

# %%
def get_thermo(filename):
    """
    read thermo logs.
    """
    with open(filename, 'r') as f:
        thermo = f.read().splitlines()
        sim_time, Et, Ep, Ek, T = [], [], [], [], []
        for i in range(1, len(thermo)):
            try:
                t, Etot, Epot, Ekin, Temp = [float(x) for x in thermo[i].split(' ') if x]
                sim_time.append(t)
                Et.append(Etot)
                Ep.append(Epot)
                Ek.append(Ekin)
                T.append(Temp)
            except:
                sim_time, Et, Ep, Ek, T = [], [], [], [], []
    thermo = {
        'time': sim_time,
        'Et': Et,
        'Ep': Ep,
        'Ek': Ek,
        'T': T
    }
    return thermo

def mae(x, y, factor):
    return np.abs(x-y).mean() * factor

def distance_pbc(x0, x1, lattices):
    delta = torch.abs(x0 - x1)
    lattices = lattices.view(-1,1,3)
    delta = torch.where(delta > 0.5 * lattices, delta - lattices, delta)
    return torch.sqrt((delta ** 2).sum(dim=-1))

# %%
def load_run(md_dir, xlim, bins, stability_threshold, gt_traj, hist_gt):
    """
    md_dir: directory to the finished MD simulation.
    """
    if not isinstance(md_dir, Path):
        md_dir = Path(md_dir)
    Dev_mean = []
    Dev_max = []
    Dev_min = []
    #model_name = md_dir.parts[-2]
    #seed = md_dir.parts[-1][-1]
    run = {'name': 'tob',}
    
    # get bonds
    traj = Trajectory(md_dir / 'simulation_300K.traj')
    atoms = traj[0]
    NL = NeighborList(natural_cutoffs(atoms), self_interaction=False)
    NL.update(atoms)
    bonds = NL.get_connectivity_matrix().todense().nonzero()
    bonds = torch.tensor(bonds)
    
    # process trajectory
    traj = [x.positions for x in traj]
    run['traj'] = torch.from_numpy(np.stack(traj))
    run['traj'] = torch.unique(run['traj'], dim=0) # remove repeated frames from restarting.

    # load thermo log
    run['thermo'] = get_thermo(md_dir / 'simulation_300K.log')
    T = np.array(run['thermo']['T']) 
    collapse_pt = len(T)
    md_time = np.array(run['thermo']['time'])
    
    # track stability
    bond_lens = distance_pbc(
        gt_traj[:, bonds[0]], gt_traj[:, bonds[1]], torch.FloatTensor([6.80,7.44,22.41])) #[11.27, 7.40, 9.51]
    mean_bond_lens = bond_lens.mean(dim=0)
    
    for i in range(1, len(T)):
        bond_lens = distance_pbc(
            run['traj'][(i-1):i, bonds[0]], run['traj'][(i-1):i, bonds[1]], torch.FloatTensor([6.80,7.44,22.41]))
        zero_bond_lens = distance_pbc(
            run['traj'][0:1, bonds[0]], run['traj'][0:1, bonds[1]], torch.FloatTensor([6.80,7.44,22.41]))
        max_dev = (bond_lens[0] - mean_bond_lens).abs().max()
        mean_dev = (bond_lens[0] - mean_bond_lens).abs().mean()
        min_dev = (bond_lens[0] - mean_bond_lens).abs().min()
        Dev_mean.append(mean_dev)
        Dev_max.append(max_dev)
        Dev_min.append(min_dev)
        if  mean_dev > stability_threshold:
            collapse_pt = i
            break
    run['collapse_pt'] = collapse_pt
    
    # compute h(r)
    hist_pred = get_hr(run['traj'][0:collapse_pt], bins)
    hr_mae = mae(hist_pred, hist_gt, xlim)
    run['hr'] = hist_pred
    run['hr_error'] = hr_mae
    run['Dev_mean'] = Dev_mean
    run['Dev_max'] = Dev_max
    run['Dev_min'] = Dev_min
    
    # load test metrics
    if (md_dir / 'test_metric.json').exists():
        test_metrics = get_test_metrics(md_dir)
        run.update(test_metrics)
    
    return run

# %%
def get_hr(traj, bins):
    """
    compute h(r) for MD17 simulations.
    traj: T x N_atoms x 3
    """
    pdist = torch.cdist(traj, traj).flatten()
    hist, _ = np.histogram(pdist[:].flatten().numpy(), bins, density=True)
    return hist

# %%
stability_threshold = 0.15
xlim = 10
n_bins = 500
bins = np.linspace(1e-6, xlim, n_bins + 1) # for computing h(r)

gt_data = np.load('tob11.npz')
gt_traj = torch.FloatTensor(gt_data.f.R)
hist_gt= get_hr(gt_traj, bins)
md_dir = './'

run = load_run(md_dir, xlim, bins, stability_threshold, gt_traj, hist_gt)

# %%
import matplotlib.pyplot as plt

x = np.arange(len(run['Dev_mean'])) / 20
y1 = run['Dev_mean']
y2 = run['Dev_max']
y3 = run['Dev_min']
y1
# Out:
# [tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(4.7220e+40, dtype=torch.float64),
#  tensor(3.0503, dtype=torch.float64),
#  tensor(3.0528, dtype=torch.float64),
#  tensor(3.0489, dtype=torch.float64),
#  tensor(3.0469, dtype=torch.float64),
#  tensor(3.0422, dtype=torch.float64),
#  tensor(3.0574, dtype=torch.float64),
#  tensor(3.0517, dtype=torch.float64),
#  tensor(3.0691, dtype=torch.float64),
#  tensor(3.0345, dtype=torch.float64),
#  tensor(3.0565, dtype=torch.float64),
#  tensor(3.0448, dtype=torch.float64),
#  tensor(3.0697, dtype=torch.float64),
#  tensor(3.0511, dtype=torch.float64),
#  tensor(3.0449, dtype=torch.float64),
#  tensor(3.0540, dtype=torch.float64),
#  tensor(3.0414, dtype=torch.float64),
#  tensor(3.0581, dtype=torch.float64),
#  tensor(3.0439, dtype=torch.float64),
#  tensor(3.0575, dtype=torch.float64),
#  tensor(3.0601, dtype=torch.float64),
#  tensor(3.0470, dtype=torch.float64),
#  tensor(3.0442, dtype=torch.float64),
#  tensor(3.0397, dtype=torch.float64),
#  tensor(3.0489, dtype=torch.float64),
#  tensor(3.0549, dtype=torch.float64),
#  tensor(3.0407, dtype=torch.float64),
#  tensor(3.0494, dtype=torch.float64),
#  tensor(3.0537, dtype=torch.float64),
#  tensor(3.0601, dtype=torch.float64),
#  tensor(3.0510, dtype=torch.float64),
#  tensor(3.0607, dtype=torch.float64),
#  tensor(3.0636, dtype=torch.float64),
#  tensor(3.0415, dtype=torch.float64),
#  tensor(3.0565, dtype=torch.float64),
#  tensor(3.0518, dtype=torch.float64),
#  tensor(3.0573, dtype=torch.float64),
#  tensor(3.0398, dtype=torch.float64),
#  tensor(3.0649, dtype=torch.float64),
#  tensor(3.0507, dtype=torch.float64),
#  tensor(3.0428, dtype=torch.float64),
#  tensor(3.0697, dtype=torch.float64),
#  tensor(3.0443, dtype=torch.float64),
#  tensor(3.0437, dtype=torch.float64),
#  tensor(3.0632, dtype=torch.float64),
#  tensor(3.0277, dtype=torch.float64),
#  tensor(3.0581, dtype=torch.float64),
#  tensor(3.0406, dtype=torch.float64),
#  tensor(3.0540, dtype=torch.float64),
#  tensor(3.0477, dtype=torch.float64),
#  tensor(3.0589, dtype=torch.float64),
#  tensor(3.0602, dtype=torch.float64),
#  tensor(3.0508, dtype=torch.float64),
#  tensor(3.0631, dtype=torch.float64),
#  tensor(3.0635, dtype=torch.float64),
#  tensor(3.0492, dtype=torch.float64),
#  tensor(3.0537, dtype=torch.float64),
#  tensor(3.0450, dtype=torch.float64),
#  tensor(3.0457, dtype=torch.float64),
#  tensor(3.0528, dtype=torch.float64),
#  tensor(3.0406, dtype=torch.float64),
#  tensor(3.0591, dtype=torch.float64),
#  tensor(3.0469, dtype=torch.float64),
#  tensor(3.0363, dtype=torch.float64),
#  tensor(3.0558, dtype=torch.float64),
#  tensor(3.0572, dtype=torch.float64),
#  tensor(3.0415, dtype=torch.float64),
#  tensor(3.0517, dtype=torch.float64),
#  tensor(3.0414, dtype=torch.float64),
#  tensor(3.0523, dtype=torch.float64),
#  tensor(3.0460, dtype=torch.float64),
#  tensor(3.0426, dtype=torch.float64),
#  tensor(3.0582, dtype=torch.float64),
#  tensor(3.0514, dtype=torch.float64),
#  tensor(3.0352, dtype=torch.float64),
#  tensor(3.0290, dtype=torch.float64),
#  tensor(3.0594, dtype=torch.float64),
#  tensor(3.0515, dtype=torch.float64),
#  tensor(3.0556, dtype=torch.float64),
#  tensor(3.0393, dtype=torch.float64),
#  tensor(3.0689, dtype=torch.float64),
#  tensor(3.0517, dtype=torch.float64),
#  tensor(3.0585, dtype=torch.float64),
#  tensor(3.0387, dtype=torch.float64),
#  tensor(3.0443, dtype=torch.float64),
#  tensor(3.0635, dtype=torch.float64),
#  tensor(3.0638, dtype=torch.float64),
#  tensor(3.0426, dtype=torch.float64),
#  tensor(3.0405, dtype=torch.float64),
#  tensor(3.0480, dtype=torch.float64),
#  tensor(3.0623, dtype=torch.float64),
#  tensor(3.0520, dtype=torch.float64),
#  tensor(3.0590, dtype=torch.float64),
#  tensor(3.0594, dtype=torch.float64),
#  tensor(3.0614, dtype=torch.float64),
#  tensor(3.0631, dtype=torch.float64),
#  tensor(3.0492, dtype=torch.float64),
#  tensor(3.0536, dtype=torch.float64),
#  tensor(3.0377, dtype=torch.float64),
#  tensor(3.0516, dtype=torch.float64),
#  tensor(3.0391, dtype=torch.float64),
#  tensor(3.0587, dtype=torch.float64),
#  tensor(3.0537, dtype=torch.float64),
#  tensor(3.0613, dtype=torch.float64),
#  tensor(3.0391, dtype=torch.float64),
#  tensor(3.0406, dtype=torch.float64),
#  tensor(3.0532, dtype=torch.float64),
#  tensor(3.0438, dtype=torch.float64),
#  tensor(3.0471, dtype=torch.float64),
#  tensor(3.0534, dtype=torch.float64),
#  tensor(3.0491, dtype=torch.float64),
#  tensor(3.0569, dtype=torch.float64),
#  tensor(3.0439, dtype=torch.float64),
#  tensor(3.0452, dtype=torch.float64),
#  tensor(3.0576, dtype=torch.float64),
#  tensor(3.0562, dtype=torch.float64),
#  tensor(3.0500, dtype=torch.float64),
#  tensor(3.0470, dtype=torch.float64),
#  tensor(3.0491, dtype=torch.float64),
#  tensor(3.0597, dtype=torch.float64),
#  tensor(3.0510, dtype=torch.float64),
#  tensor(3.0685, dtype=torch.float64),
#  tensor(3.0431, dtype=torch.float64),
#  tensor(3.0589, dtype=torch.float64),
#  tensor(3.0593, dtype=torch.float64),
#  tensor(3.0586, dtype=torch.float64),
#  tensor(3.0516, dtype=torch.float64),
#  tensor(3.0627, dtype=torch.float64),
#  tensor(3.0639, dtype=torch.float64),
#  tensor(3.0519, dtype=torch.float64),
#  tensor(3.0624, dtype=torch.float64),
#  tensor(3.0532, dtype=torch.float64),
#  tensor(3.0458, dtype=torch.float64),
#  tensor(3.0637, dtype=torch.float64),
#  tensor(3.0578, dtype=torch.float64),
#  tensor(3.0518, dtype=torch.float64),
#  tensor(3.0452, dtype=torch.float64),
#  tensor(3.0668, dtype=torch.float64),
#  tensor(3.0659, dtype=torch.float64),
#  tensor(3.0466, dtype=torch.float64),
#  tensor(3.0558, dtype=torch.float64),
#  tensor(3.0555, dtype=torch.float64),
#  tensor(3.0436, dtype=torch.float64),
#  tensor(3.0708, dtype=torch.float64),
#  tensor(3.0530, dtype=torch.float64),
#  tensor(3.0537, dtype=torch.float64),
#  tensor(3.0498, dtype=torch.float64),
#  tensor(3.0641, dtype=torch.float64),
#  tensor(3.0385, dtype=torch.float64),
#  tensor(3.0541, dtype=torch.float64),
#  tensor(3.0457, dtype=torch.float64),
#  tensor(3.0528, dtype=torch.float64),
#  tensor(3.0507, dtype=torch.float64),
#  tensor(3.0333, dtype=torch.float64),
#  tensor(3.0484, dtype=torch.float64),
#  tensor(3.0450, dtype=torch.float64),
#  tensor(3.0590, dtype=torch.float64),
#  tensor(3.0510, dtype=torch.float64),
#  tensor(3.0487, dtype=torch.float64),
#  tensor(3.0486, dtype=torch.float64),
#  tensor(3.0595, dtype=torch.float64),
#  tensor(3.0441, dtype=torch.float64),
#  tensor(3.0490, dtype=torch.float64),
#  tensor(3.0487, dtype=torch.float64),
#  tensor(3.0538, dtype=torch.float64),
#  tensor(3.0478, dtype=torch.float64),
#  tensor(3.0319, dtype=torch.float64),
#  tensor(3.0677, dtype=torch.float64),
#  tensor(3.0457, dtype=torch.float64),
#  tensor(3.0618, dtype=torch.float64),
#  tensor(3.0352, dtype=torch.float64),
#  tensor(3.0432, dtype=torch.float64),
#  tensor(3.0534, dtype=torch.float64),
#  tensor(3.0617, dtype=torch.float64),
#  tensor(3.0547, dtype=torch.float64),
#  tensor(3.0335, dtype=torch.float64),
#  tensor(3.0514, dtype=torch.float64),
#  tensor(3.0395, dtype=torch.float64),
#  tensor(3.0521, dtype=torch.float64),
#  tensor(3.0509, dtype=torch.float64),
#  tensor(3.0326, dtype=torch.float64),
#  tensor(3.0544, dtype=torch.float64),
#  tensor(3.0574, dtype=torch.float64),
#  tensor(3.0464, dtype=torch.float64),
#  tensor(3.0544, dtype=torch.float64),
#  tensor(3.0452, dtype=torch.float64),
#  tensor(3.0435, dtype=torch.float64),
#  tensor(3.0451, dtype=torch.float64),
#  tensor(3.0420, dtype=torch.float64),
#  tensor(3.0452, dtype=torch.float64),
#  tensor(3.0440, dtype=torch.float64),
#  tensor(3.0544, dtype=torch.float64),
#  tensor(3.0538, dtype=torch.float64),
#  tensor(3.0522, dtype=torch.float64),
#  tensor(3.0551, dtype=torch.float64),
#  tensor(3.0612, dtype=torch.float64),
#  tensor(3.0465, dtype=torch.float64),
#  tensor(3.0594, dtype=torch.float64),
#  tensor(3.0476, dtype=torch.float64),
#  tensor(3.0537, dtype=torch.float64),
#  tensor(3.0501, dtype=torch.float64),
#  tensor(3.0581, dtype=torch.float64),
#  tensor(3.0629, dtype=torch.float64),
#  tensor(3.0586, dtype=torch.float64),
#  tensor(3.0607, dtype=torch.float64),
#  tensor(3.0527, dtype=torch.float64),
#  tensor(3.0703, dtype=torch.float64),
#  tensor(3.0605, dtype=torch.float64),
#  tensor(3.0493, dtype=torch.float64),
#  tensor(3.0340, dtype=torch.float64),
#  tensor(3.0533, dtype=torch.float64),
#  tensor(3.0520, dtype=torch.float64),
#  tensor(3.0479, dtype=torch.float64),
#  tensor(3.0459, dtype=torch.float64),
#  tensor(3.0358, dtype=torch.float64),
#  tensor(3.0549, dtype=torch.float64),
#  tensor(3.0403, dtype=torch.float64),
#  tensor(3.0446, dtype=torch.float64),
#  tensor(3.0453, dtype=torch.float64),
#  tensor(3.0396, dtype=torch.float64),
#  tensor(3.0637, dtype=torch.float64),
#  tensor(3.0449, dtype=torch.float64),
#  tensor(3.0524, dtype=torch.float64),
#  tensor(3.0499, dtype=torch.float64),
#  tensor(3.0536, dtype=torch.float64),
#  tensor(3.0576, dtype=torch.float64),
#  tensor(3.0341, dtype=torch.float64),
#  tensor(3.0561, dtype=torch.float64),
#  tensor(3.0588, dtype=torch.float64),
#  tensor(3.0601, dtype=torch.float64),
#  tensor(3.0656, dtype=torch.float64),
#  tensor(3.0509, dtype=torch.float64),
#  tensor(3.0455, dtype=torch.float64),
#  tensor(3.0568, dtype=torch.float64),
#  tensor(3.0553, dtype=torch.float64),
#  tensor(3.0457, dtype=torch.float64),
#  tensor(3.0515, dtype=torch.float64),
#  tensor(3.0319, dtype=torch.float64),
#  tensor(3.0598, dtype=torch.float64),
#  tensor(3.0588, dtype=torch.float64),
#  tensor(3.0582, dtype=torch.float64),
#  tensor(3.0402, dtype=torch.float64),
#  tensor(3.0468, dtype=torch.float64),
#  tensor(3.0444, dtype=torch.float64),
#  tensor(3.0536, dtype=torch.float64),
#  tensor(3.0407, dtype=torch.float64),
#  tensor(3.0536, dtype=torch.float64),
#  tensor(3.0550, dtype=torch.float64),
#  tensor(3.0623, dtype=torch.float64),
#  tensor(3.0636, dtype=torch.float64),
#  tensor(3.0512, dtype=torch.float64),
#  tensor(3.0541, dtype=torch.float64),
#  tensor(3.0462, dtype=torch.float64),
#  tensor(3.0325, dtype=torch.float64),
#  tensor(3.0465, dtype=torch.float64),
#  tensor(3.0692, dtype=torch.float64),
#  tensor(3.0471, dtype=torch.float64),
#  tensor(3.0592, dtype=torch.float64),
#  tensor(3.0427, dtype=torch.float64),
#  tensor(3.0333, dtype=torch.float64),
#  tensor(3.0525, dtype=torch.float64),
#  tensor(3.0472, dtype=torch.float64),
#  tensor(3.0566, dtype=torch.float64),
#  tensor(3.0481, dtype=torch.float64),
#  tensor(3.0662, dtype=torch.float64),
#  tensor(3.0470, dtype=torch.float64),
#  tensor(3.0503, dtype=torch.float64),
#  tensor(3.0563, dtype=torch.float64),
#  tensor(3.0579, dtype=torch.float64),
#  tensor(3.0363, dtype=torch.float64),
#  tensor(3.0471, dtype=torch.float64),
#  tensor(3.0412, dtype=torch.float64),
#  tensor(3.0522, dtype=torch.float64),
#  tensor(3.0543, dtype=torch.float64),
#  tensor(3.0446, dtype=torch.float64),
#  tensor(3.0525, dtype=torch.float64),
#  tensor(3.0546, dtype=torch.float64),
#  tensor(3.0565, dtype=torch.float64),
#  tensor(3.0544, dtype=torch.float64),
#  tensor(3.0428, dtype=torch.float64),
#  tensor(3.0448, dtype=torch.float64),
#  tensor(3.0402, dtype=torch.float64),
#  tensor(3.0633, dtype=torch.float64),
#  tensor(3.0636, dtype=torch.float64),
#  tensor(3.0506, dtype=torch.float64),
#  tensor(3.0555, dtype=torch.float64),
#  tensor(3.0519, dtype=torch.float64),
#  tensor(3.0667, dtype=torch.float64),
#  tensor(3.0478, dtype=torch.float64),
#  tensor(3.0424, dtype=torch.float64),
#  tensor(3.0581, dtype=torch.float64),
#  tensor(3.0521, dtype=torch.float64),
#  tensor(3.0464, dtype=torch.float64),
#  tensor(3.0489, dtype=torch.float64),
#  tensor(3.0563, dtype=torch.float64),
#  tensor(3.0560, dtype=torch.float64),
#  tensor(3.0634, dtype=torch.float64),
#  tensor(3.0641, dtype=torch.float64),
#  tensor(3.0685, dtype=torch.float64),
#  tensor(3.0608, dtype=torch.float64),
#  tensor(3.0518, dtype=torch.float64),
#  tensor(3.0555, dtype=torch.float64),
#  tensor(3.0438, dtype=torch.float64),
#  tensor(3.0516, dtype=torch.float64),
#  tensor(3.0600, dtype=torch.float64),
#  tensor(3.0407, dtype=torch.float64),
#  tensor(3.0486, dtype=torch.float64),
#  tensor(3.0452, dtype=torch.float64),
#  tensor(3.0650, dtype=torch.float64),
#  tensor(3.0594, dtype=torch.float64),
#  tensor(3.0569, dtype=torch.float64),
#  tensor(3.0636, dtype=torch.float64),
#  tensor(3.0541, dtype=torch.float64),
#  tensor(3.0684, dtype=torch.float64),
#  tensor(3.0404, dtype=torch.float64),
#  tensor(3.0440, dtype=torch.float64),
#  tensor(3.0447, dtype=torch.float64),
#  tensor(3.0471, dtype=torch.float64),
#  tensor(3.0660, dtype=torch.float64),
#  tensor(3.0522, dtype=torch.float64),
#  tensor(3.0583, dtype=torch.float64),
#  tensor(3.0400, dtype=torch.float64),
#  tensor(3.0477, dtype=torch.float64),
#  tensor(3.0638, dtype=torch.float64),
#  tensor(3.0584, dtype=torch.float64),
#  tensor(3.0542, dtype=torch.float64),
#  tensor(3.0465, dtype=torch.float64),
#  tensor(3.0485, dtype=torch.float64),
#  tensor(3.0535, dtype=torch.float64),
#  tensor(3.0435, dtype=torch.float64),
#  tensor(3.0506, dtype=torch.float64),
#  tensor(3.0507, dtype=torch.float64),
#  tensor(3.0445, dtype=torch.float64),
#  tensor(3.0655, dtype=torch.float64),
#  tensor(3.0497, dtype=torch.float64),
#  tensor(3.0616, dtype=torch.float64),
#  tensor(3.0510, dtype=torch.float64),
#  tensor(3.0529, dtype=torch.float64),
#  tensor(3.0552, dtype=torch.float64),
#  tensor(3.0534, dtype=torch.float64),
#  tensor(3.0620, dtype=torch.float64),
#  tensor(3.0590, dtype=torch.float64),
#  tensor(3.0427, dtype=torch.float64),
#  tensor(3.0597, dtype=torch.float64),
#  tensor(3.0627, dtype=torch.float64),
#  tensor(3.0454, dtype=torch.float64),
#  tensor(3.0464, dtype=torch.float64),
#  tensor(3.0532, dtype=torch.float64),
#  tensor(3.0471, dtype=torch.float64),
#  tensor(3.0596, dtype=torch.float64),
#  tensor(3.0505, dtype=torch.float64),
#  tensor(3.0578, dtype=torch.float64),
#  tensor(3.0558, dtype=torch.float64),
#  tensor(3.0458, dtype=torch.float64),
#  tensor(3.0575, dtype=torch.float64),
#  tensor(3.0623, dtype=torch.float64),
#  tensor(3.0552, dtype=torch.float64),
#  tensor(3.0580, dtype=torch.float64),
#  tensor(3.0497, dtype=torch.float64),
#  tensor(3.0347, dtype=torch.float64),
#  tensor(3.0455, dtype=torch.float64),
#  tensor(3.0552, dtype=torch.float64),
#  tensor(3.0586, dtype=torch.float64),
#  tensor(3.0574, dtype=torch.float64),
#  tensor(3.0554, dtype=torch.float64),
#  tensor(3.0693, dtype=torch.float64),
#  tensor(3.0358, dtype=torch.float64),
#  tensor(3.0563, dtype=torch.float64),
#  tensor(3.0507, dtype=torch.float64),
#  tensor(3.0532, dtype=torch.float64),
#  tensor(3.0612, dtype=torch.float64),
#  tensor(3.0525, dtype=torch.float64),
#  tensor(3.0495, dtype=torch.float64),
#  tensor(3.0396, dtype=torch.float64),
#  tensor(3.0527, dtype=torch.float64),
#  tensor(3.0475, dtype=torch.float64),
#  tensor(3.0526, dtype=torch.float64),
#  tensor(3.0694, dtype=torch.float64),
#  tensor(3.0482, dtype=torch.float64),
#  tensor(3.0411, dtype=torch.float64),
#  tensor(3.0613, dtype=torch.float64),
#  tensor(3.0596, dtype=torch.float64),
#  tensor(3.0449, dtype=torch.float64),
#  tensor(3.0519, dtype=torch.float64),
#  tensor(3.0540, dtype=torch.float64),
#  tensor(3.0556, dtype=torch.float64),
#  tensor(3.0580, dtype=torch.float64),
#  tensor(3.0627, dtype=torch.float64),
#  tensor(3.0459, dtype=torch.float64),
#  tensor(3.0619, dtype=torch.float64),
#  tensor(3.0599, dtype=torch.float64),
#  tensor(3.0639, dtype=torch.float64),
#  tensor(3.0452, dtype=torch.float64),
#  tensor(3.0573, dtype=torch.float64),
#  tensor(3.0559, dtype=torch.float64),
#  tensor(3.0414, dtype=torch.float64),
#  tensor(3.0520, dtype=torch.float64),
#  tensor(3.0510, dtype=torch.float64),
#  tensor(3.0551, dtype=torch.float64),
#  tensor(3.0474, dtype=torch.float64),
#  tensor(3.0642, dtype=torch.float64),
#  tensor(3.0526, dtype=torch.float64),
#  tensor(3.0597, dtype=torch.float64),
#  tensor(3.0443, dtype=torch.float64),
#  tensor(3.0525, dtype=torch.float64),
#  tensor(3.0578, dtype=torch.float64),
#  tensor(3.0507, dtype=torch.float64),
#  tensor(3.0554, dtype=torch.float64),
#  tensor(3.0496, dtype=torch.float64),
#  tensor(3.0527, dtype=torch.float64),
#  tensor(3.0646, dtype=torch.float64),
#  tensor(3.0538, dtype=torch.float64),
#  tensor(3.0472, dtype=torch.float64),
#  tensor(3.0452, dtype=torch.float64),
#  tensor(3.0501, dtype=torch.float64),
#  tensor(3.0505, dtype=torch.float64),
#  tensor(3.0480, dtype=torch.float64),
#  tensor(3.0587, dtype=torch.float64),
#  tensor(3.0499, dtype=torch.float64),
#  tensor(3.0459, dtype=torch.float64),
#  tensor(3.0428, dtype=torch.float64),
#  tensor(3.0505, dtype=torch.float64),
#  tensor(3.0527, dtype=torch.float64),
#  tensor(3.0476, dtype=torch.float64),
#  tensor(3.0606, dtype=torch.float64),
#  tensor(3.0597, dtype=torch.float64),
#  tensor(3.0592, dtype=torch.float64),
#  tensor(3.0530, dtype=torch.float64),
#  tensor(3.0405, dtype=torch.float64),
#  tensor(3.0647, dtype=torch.float64),
#  tensor(3.0461, dtype=torch.float64),
#  tensor(3.0586, dtype=torch.float64),
#  tensor(3.0465, dtype=torch.float64),
#  tensor(3.0553, dtype=torch.float64),
#  tensor(3.0574, dtype=torch.float64),
#  tensor(3.0445, dtype=torch.float64),
#  tensor(3.0562, dtype=torch.float64),
#  tensor(3.0535, dtype=torch.float64),
#  tensor(3.0469, dtype=torch.float64),
#  tensor(3.0511, dtype=torch.float64),
#  tensor(3.0575, dtype=torch.float64),
#  tensor(3.0607, dtype=torch.float64),
#  tensor(3.0440, dtype=torch.float64),
#  tensor(3.0530, dtype=torch.float64),
#  tensor(3.0345, dtype=torch.float64),
#  tensor(3.0456, dtype=torch.float64),
#  tensor(3.0557, dtype=torch.float64),
#  tensor(3.0559, dtype=torch.float64),
#  tensor(3.0454, dtype=torch.float64),
#  tensor(3.0557, dtype=torch.float64),
#  tensor(3.0499, dtype=torch.float64),
#  tensor(3.0380, dtype=torch.float64),
#  tensor(3.0407, dtype=torch.float64),
#  tensor(3.0623, dtype=torch.float64),
#  tensor(3.0506, dtype=torch.float64),
#  tensor(3.0592, dtype=torch.float64),
#  tensor(3.0629, dtype=torch.float64),
#  tensor(3.0552, dtype=torch.float64),
#  tensor(3.0499, dtype=torch.float64),
#  tensor(3.0555, dtype=torch.float64),
#  tensor(3.0593, dtype=torch.float64),
#  tensor(3.0579, dtype=torch.float64),
#  tensor(3.0495, dtype=torch.float64),
#  tensor(3.0765, dtype=torch.float64),
#  tensor(3.0493, dtype=torch.float64),
#  tensor(3.0547, dtype=torch.float64),
#  tensor(3.0619, dtype=torch.float64),
#  tensor(3.0572, dtype=torch.float64),
#  tensor(3.0595, dtype=torch.float64),
#  tensor(3.0619, dtype=torch.float64),
#  tensor(3.0602, dtype=torch.float64),
#  tensor(3.0634, dtype=torch.float64),
#  tensor(3.0542, dtype=torch.float64),
#  tensor(3.0516, dtype=torch.float64),
#  tensor(3.0450, dtype=torch.float64),
#  tensor(3.0542, dtype=torch.float64),
#  tensor(3.0462, dtype=torch.float64),
#  tensor(3.0382, dtype=torch.float64),
#  tensor(3.0482, dtype=torch.float64),
#  tensor(3.0435, dtype=torch.float64),
#  tensor(3.0562, dtype=torch.float64),
#  tensor(3.0617, dtype=torch.float64),
#  tensor(3.0465, dtype=torch.float64),
#  tensor(3.0508, dtype=torch.float64),
#  tensor(3.0490, dtype=torch.float64),
#  tensor(3.0411, dtype=torch.float64),
#  tensor(3.0429, dtype=torch.float64),
#  tensor(3.0606, dtype=torch.float64),
#  tensor(3.0503, dtype=torch.float64),
#  tensor(3.0507, dtype=torch.float64),
#  tensor(3.0523, dtype=torch.float64),
#  tensor(3.0601, dtype=torch.float64),
#  tensor(3.0497, dtype=torch.float64),
#  tensor(3.0493, dtype=torch.float64),
#  tensor(3.0477, dtype=torch.float64),
#  tensor(3.0550, dtype=torch.float64),
#  tensor(3.0564, dtype=torch.float64),
#  tensor(3.0516, dtype=torch.float64),
#  tensor(3.0540, dtype=torch.float64),
#  tensor(3.0626, dtype=torch.float64),
#  tensor(3.0612, dtype=torch.float64),
#  tensor(3.0537, dtype=torch.float64),
#  tensor(3.0619, dtype=torch.float64),
#  tensor(3.0544, dtype=torch.float64),
#  tensor(3.0533, dtype=torch.float64),
#  tensor(3.0529, dtype=torch.float64),
#  tensor(3.0654, dtype=torch.float64),
#  tensor(3.0411, dtype=torch.float64),
#  tensor(3.0508, dtype=torch.float64),
#  tensor(3.0630, dtype=torch.float64),
#  tensor(3.0503, dtype=torch.float64),
#  tensor(3.0463, dtype=torch.float64),
#  tensor(3.0559, dtype=torch.float64),
#  tensor(3.0562, dtype=torch.float64),
#  tensor(3.0634, dtype=torch.float64),
#  tensor(3.0521, dtype=torch.float64),
#  tensor(3.0595, dtype=torch.float64),
#  tensor(3.0496, dtype=torch.float64),
#  tensor(3.0482, dtype=torch.float64),
#  tensor(3.0517, dtype=torch.float64),
#  tensor(3.0660, dtype=torch.float64),
#  tensor(3.0661, dtype=torch.float64),
#  tensor(3.0576, dtype=torch.float64),
#  tensor(3.0634, dtype=torch.float64),
#  tensor(3.0537, dtype=torch.float64),
#  tensor(3.0490, dtype=torch.float64),
#  tensor(3.0578, dtype=torch.float64),
#  tensor(3.0428, dtype=torch.float64),
#  tensor(3.0316, dtype=torch.float64),
#  tensor(3.0502, dtype=torch.float64),
#  tensor(3.0520, dtype=torch.float64),
#  tensor(3.0461, dtype=torch.float64),
#  tensor(3.0617, dtype=torch.float64),
#  tensor(3.0487, dtype=torch.float64),
#  tensor(3.0465, dtype=torch.float64),
#  tensor(3.0476, dtype=torch.float64),
#  tensor(3.0592, dtype=torch.float64),
#  tensor(3.0580, dtype=torch.float64),
#  tensor(3.0447, dtype=torch.float64),
#  tensor(3.0435, dtype=torch.float64),
#  tensor(3.0521, dtype=torch.float64),
#  tensor(3.0438, dtype=torch.float64),
#  tensor(3.0587, dtype=torch.float64),
#  tensor(3.0438, dtype=torch.float64),
#  tensor(3.0410, dtype=torch.float64),
#  tensor(3.0514, dtype=torch.float64),
#  tensor(3.0499, dtype=torch.float64),
#  tensor(3.0601, dtype=torch.float64),
#  tensor(3.0375, dtype=torch.float64),
#  tensor(3.0453, dtype=torch.float64),
#  tensor(3.0577, dtype=torch.float64),
#  tensor(3.0542, dtype=torch.float64),
#  tensor(3.0422, dtype=torch.float64),
#  tensor(3.0533, dtype=torch.float64),
#  tensor(3.0693, dtype=torch.float64),
#  tensor(3.0599, dtype=torch.float64),
#  tensor(3.0454, dtype=torch.float64),
#  tensor(3.0565, dtype=torch.float64),
#  tensor(3.0305, dtype=torch.float64),
#  tensor(3.0643, dtype=torch.float64),
#  tensor(3.0500, dtype=torch.float64),
#  tensor(3.0434, dtype=torch.float64),
#  tensor(3.0533, dtype=torch.float64),
#  tensor(3.0465, dtype=torch.float64),
#  tensor(3.0623, dtype=torch.float64),
#  tensor(3.0480, dtype=torch.float64),
#  tensor(3.0613, dtype=torch.float64),
#  tensor(3.0564, dtype=torch.float64),
#  tensor(3.0459, dtype=torch.float64),
#  tensor(3.0568, dtype=torch.float64),
#  tensor(3.0545, dtype=torch.float64),
#  tensor(3.0492, dtype=torch.float64),
#  tensor(3.0611, dtype=torch.float64),
#  tensor(3.0667, dtype=torch.float64),
#  tensor(3.0391, dtype=torch.float64),
#  tensor(3.0455, dtype=torch.float64),
#  tensor(3.0659, dtype=torch.float64),
#  tensor(3.0453, dtype=torch.float64),
#  tensor(3.0497, dtype=torch.float64),
#  tensor(3.0595, dtype=torch.float64),
#  tensor(3.0499, dtype=torch.float64),
#  tensor(3.0561, dtype=torch.float64),
#  tensor(3.0630, dtype=torch.float64),
#  tensor(3.0526, dtype=torch.float64),
#  tensor(3.0564, dtype=torch.float64),
#  tensor(3.0558, dtype=torch.float64),
#  tensor(3.0471, dtype=torch.float64),
#  tensor(3.0437, dtype=torch.float64),
#  tensor(3.0378, dtype=torch.float64),
#  tensor(3.0547, dtype=torch.float64),
#  tensor(3.0530, dtype=torch.float64),
#  tensor(3.0544, dtype=torch.float64),
#  tensor(3.0614, dtype=torch.float64),
#  tensor(3.0650, dtype=torch.float64),
#  tensor(3.0403, dtype=torch.float64),
#  tensor(3.0487, dtype=torch.float64),
#  tensor(3.0363, dtype=torch.float64),
#  tensor(3.0416, dtype=torch.float64),
#  tensor(3.0328, dtype=torch.float64),
#  tensor(3.0435, dtype=torch.float64),
#  tensor(3.0459, dtype=torch.float64),
#  tensor(3.0623, dtype=torch.float64),
#  tensor(3.0749, dtype=torch.float64),
#  tensor(3.0579, dtype=torch.float64),
#  tensor(3.0466, dtype=torch.float64),
#  tensor(3.0460, dtype=torch.float64),
#  tensor(3.0609, dtype=torch.float64),
#  tensor(3.0512, dtype=torch.float64),
#  tensor(3.0589, dtype=torch.float64),
#  tensor(3.0524, dtype=torch.float64),
#  tensor(3.0632, dtype=torch.float64),
#  tensor(3.0574, dtype=torch.float64),
#  tensor(3.0624, dtype=torch.float64),
#  tensor(3.0563, dtype=torch.float64),
#  tensor(3.0512, dtype=torch.float64),
#  tensor(3.0462, dtype=torch.float64),
#  tensor(3.0565, dtype=torch.float64),
#  tensor(3.0588, dtype=torch.float64),
#  tensor(3.0470, dtype=torch.float64),
#  tensor(3.0620, dtype=torch.float64),
#  tensor(3.0618, dtype=torch.float64),
#  tensor(3.0488, dtype=torch.float64),
#  tensor(3.0641, dtype=torch.float64),
#  tensor(3.0476, dtype=torch.float64),
#  tensor(3.0507, dtype=torch.float64),
#  tensor(3.0595, dtype=torch.float64),
#  tensor(3.0486, dtype=torch.float64),
#  tensor(3.0594, dtype=torch.float64),
#  tensor(3.0576, dtype=torch.float64),
#  tensor(3.0642, dtype=torch.float64),
#  tensor(3.0507, dtype=torch.float64),
#  tensor(3.0544, dtype=torch.float64),
#  tensor(3.0495, dtype=torch.float64),
#  tensor(3.0389, dtype=torch.float64),
#  tensor(3.0573, dtype=torch.float64),
#  tensor(3.0410, dtype=torch.float64),
#  tensor(3.0508, dtype=torch.float64),
#  tensor(3.0442, dtype=torch.float64),
#  tensor(3.0516, dtype=torch.float64),
#  tensor(3.0555, dtype=torch.float64),
#  tensor(3.0546, dtype=torch.float64),
#  tensor(3.0600, dtype=torch.float64),
#  tensor(3.0580, dtype=torch.float64),
#  tensor(3.0381, dtype=torch.float64),
#  tensor(3.0628, dtype=torch.float64),
#  tensor(3.0503, dtype=torch.float64),
#  tensor(3.0516, dtype=torch.float64),
#  tensor(3.0399, dtype=torch.float64),
#  tensor(3.0550, dtype=torch.float64),
#  tensor(3.0373, dtype=torch.float64),
#  tensor(3.0510, dtype=torch.float64),
#  tensor(3.0625, dtype=torch.float64),
#  tensor(3.0539, dtype=torch.float64),
#  tensor(3.0495, dtype=torch.float64),
#  tensor(3.0622, dtype=torch.float64),
#  tensor(3.0489, dtype=torch.float64),
#  tensor(3.0520, dtype=torch.float64),
#  tensor(3.0559, dtype=torch.float64),
#  tensor(3.0514, dtype=torch.float64),
#  tensor(3.0520, dtype=torch.float64),
#  tensor(3.0456, dtype=torch.float64),
#  tensor(3.0477, dtype=torch.float64),
#  tensor(3.0475, dtype=torch.float64),
#  tensor(3.0545, dtype=torch.float64),
#  tensor(3.0504, dtype=torch.float64),
#  tensor(3.0613, dtype=torch.float64),
#  tensor(3.0568, dtype=torch.float64),
#  tensor(3.0419, dtype=torch.float64),
#  tensor(3.0501, dtype=torch.float64),
#  tensor(3.0586, dtype=torch.float64),
#  tensor(3.0407, dtype=torch.float64),
#  tensor(3.0664, dtype=torch.float64),
#  tensor(3.0482, dtype=torch.float64),
#  tensor(3.0520, dtype=torch.float64),
#  tensor(3.0431, dtype=torch.float64),
#  tensor(3.0539, dtype=torch.float64),
#  tensor(3.0472, dtype=torch.float64),
#  tensor(3.0450, dtype=torch.float64),
#  tensor(3.0413, dtype=torch.float64),
#  tensor(3.0637, dtype=torch.float64),
#  tensor(3.0378, dtype=torch.float64),
#  tensor(3.0533, dtype=torch.float64),
#  tensor(3.0521, dtype=torch.float64),
#  tensor(3.0481, dtype=torch.float64),
#  tensor(3.0660, dtype=torch.float64),
#  tensor(3.0502, dtype=torch.float64),
#  tensor(3.0452, dtype=torch.float64),
#  tensor(3.0540, dtype=torch.float64),
#  tensor(3.0450, dtype=torch.float64),
#  tensor(3.0638, dtype=torch.float64),
#  tensor(3.0421, dtype=torch.float64),
#  tensor(3.0564, dtype=torch.float64),
#  tensor(3.0373, dtype=torch.float64),
#  tensor(3.0586, dtype=torch.float64),
#  tensor(3.0530, dtype=torch.float64),
#  tensor(3.0618, dtype=torch.float64),
#  tensor(3.0644, dtype=torch.float64),
#  tensor(3.0594, dtype=torch.float64),
#  tensor(3.0582, dtype=torch.float64),
#  tensor(3.0496, dtype=torch.float64),
#  tensor(3.0467, dtype=torch.float64),
#  tensor(3.0507, dtype=torch.float64),
#  tensor(3.0447, dtype=torch.float64),
#  tensor(3.0432, dtype=torch.float64),
#  tensor(3.0561, dtype=torch.float64),
#  tensor(3.0574, dtype=torch.float64),
#  tensor(3.0428, dtype=torch.float64),
#  tensor(3.0604, dtype=torch.float64),
#  tensor(3.0540, dtype=torch.float64),
#  tensor(3.0684, dtype=torch.float64),
#  tensor(3.0332, dtype=torch.float64),
#  tensor(3.0521, dtype=torch.float64),
#  tensor(3.0473, dtype=torch.float64),
#  tensor(3.0592, dtype=torch.float64),
#  tensor(3.0595, dtype=torch.float64),
#  tensor(3.0416, dtype=torch.float64),
#  tensor(3.0482, dtype=torch.float64),
#  tensor(3.0534, dtype=torch.float64),
#  tensor(3.0584, dtype=torch.float64),
#  tensor(3.0657, dtype=torch.float64),
#  tensor(3.0387, dtype=torch.float64),
#  tensor(3.0632, dtype=torch.float64),
#  tensor(3.0490, dtype=torch.float64),
#  tensor(3.0466, dtype=torch.float64),
#  tensor(3.0550, dtype=torch.float64),
#  tensor(3.0548, dtype=torch.float64),
#  tensor(3.0509, dtype=torch.float64),
#  tensor(3.0749, dtype=torch.float64),
#  tensor(3.0502, dtype=torch.float64),
#  tensor(3.0603, dtype=torch.float64),
#  tensor(3.0394, dtype=torch.float64),
#  tensor(3.0471, dtype=torch.float64),
#  tensor(3.0622, dtype=torch.float64),
#  tensor(3.0586, dtype=torch.float64),
#  tensor(3.0519, dtype=torch.float64),
#  tensor(3.0553, dtype=torch.float64),
#  tensor(3.0576, dtype=torch.float64),
#  tensor(3.0480, dtype=torch.float64),
#  tensor(3.0490, dtype=torch.float64),
#  tensor(3.0384, dtype=torch.float64),
#  tensor(3.0499, dtype=torch.float64),
#  tensor(3.0548, dtype=torch.float64),
#  tensor(3.0553, dtype=torch.float64),
#  tensor(3.0344, dtype=torch.float64),
#  tensor(3.0572, dtype=torch.float64),
#  tensor(3.0573, dtype=torch.float64),
#  tensor(3.0493, dtype=torch.float64),
#  tensor(3.0574, dtype=torch.float64),
#  tensor(3.0496, dtype=torch.float64),
#  tensor(3.0476, dtype=torch.float64),
#  tensor(3.0620, dtype=torch.float64),
#  tensor(3.0512, dtype=torch.float64),
#  tensor(3.0452, dtype=torch.float64),
#  tensor(3.0500, dtype=torch.float64),
#  tensor(3.0505, dtype=torch.float64),
#  tensor(3.0430, dtype=torch.float64),
#  tensor(3.0635, dtype=torch.float64),
#  tensor(3.0634, dtype=torch.float64),
#  tensor(3.0648, dtype=torch.float64),
#  tensor(3.0586, dtype=torch.float64),
#  tensor(3.0311, dtype=torch.float64),
#  tensor(3.0588, dtype=torch.float64),
#  tensor(3.0522, dtype=torch.float64),
#  tensor(3.0551, dtype=torch.float64),
#  tensor(3.0539, dtype=torch.float64),
#  tensor(3.0438, dtype=torch.float64),
#  tensor(3.0583, dtype=torch.float64),
#  tensor(3.0516, dtype=torch.float64),
#  tensor(3.0412, dtype=torch.float64),
#  tensor(3.0541, dtype=torch.float64),
#  tensor(3.0474, dtype=torch.float64),
#  tensor(3.0510, dtype=torch.float64),
#  tensor(3.0543, dtype=torch.float64),
#  tensor(3.0655, dtype=torch.float64),
#  tensor(3.0516, dtype=torch.float64),
#  tensor(3.0620, dtype=torch.float64),
#  tensor(3.0590, dtype=torch.float64),
#  tensor(3.0457, dtype=torch.float64),
#  tensor(3.0530, dtype=torch.float64),
#  tensor(3.0385, dtype=torch.float64),
#  tensor(3.0396, dtype=torch.float64),
#  tensor(3.0478, dtype=torch.float64),
#  tensor(3.0434, dtype=torch.float64),
#  tensor(3.0622, dtype=torch.float64),
#  tensor(3.0522, dtype=torch.float64),
#  tensor(3.0492, dtype=torch.float64),
#  tensor(3.0504, dtype=torch.float64),
#  tensor(3.0415, dtype=torch.float64),
#  tensor(3.0510, dtype=torch.float64),
#  tensor(3.0513, dtype=torch.float64),
#  tensor(3.0368, dtype=torch.float64),
#  tensor(3.0534, dtype=torch.float64),
#  tensor(3.0410, dtype=torch.float64),
#  tensor(3.0544, dtype=torch.float64),
#  tensor(3.0357, dtype=torch.float64),
#  tensor(3.0458, dtype=torch.float64),
#  tensor(3.0495, dtype=torch.float64),
#  tensor(3.0325, dtype=torch.float64),
#  tensor(3.0518, dtype=torch.float64),
#  tensor(3.0448, dtype=torch.float64),
#  tensor(3.0583, dtype=torch.float64),
#  tensor(3.0572, dtype=torch.float64),
#  tensor(3.0672, dtype=torch.float64),
#  tensor(3.0543, dtype=torch.float64),
#  tensor(3.0542, dtype=torch.float64),
#  tensor(3.0420, dtype=torch.float64),
#  tensor(3.0564, dtype=torch.float64),
#  tensor(3.0486, dtype=torch.float64),
#  tensor(3.0493, dtype=torch.float64),
#  tensor(3.0520, dtype=torch.float64),
#  tensor(3.0498, dtype=torch.float64),
#  tensor(3.0497, dtype=torch.float64),
#  tensor(3.0554, dtype=torch.float64),
#  tensor(3.0563, dtype=torch.float64),
#  tensor(3.0436, dtype=torch.float64),
#  tensor(3.0599, dtype=torch.float64),
#  tensor(3.0468, dtype=torch.float64),
#  tensor(3.0393, dtype=torch.float64),
#  tensor(3.0466, dtype=torch.float64),
#  tensor(3.0525, dtype=torch.float64),
#  tensor(3.0436, dtype=torch.float64),
#  tensor(3.0558, dtype=torch.float64),
#  tensor(3.0422, dtype=torch.float64),
#  tensor(3.0724, dtype=torch.float64),
#  tensor(3.0503, dtype=torch.float64),
#  tensor(3.0489, dtype=torch.float64),
#  tensor(3.0522, dtype=torch.float64),
#  ...]

# %%
collapse_ps = (run['collapse_pt']-1) / 20
hr_mae = run['hr_error']

print(f'stability: {collapse_ps:.1f} ps \nh(r) mae: {hr_mae:.3f}')
# Out:
# stability: 70.4 ps
# h(r) mae: 0.058
