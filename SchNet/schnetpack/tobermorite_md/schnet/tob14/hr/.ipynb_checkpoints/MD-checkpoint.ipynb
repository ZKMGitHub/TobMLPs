# %%
from ase import Atoms, io
import torch
import schnetpack as spk
from schnetpack.data import AtomsDataModule
from schnetpack.datasets import MD17
import schnetpack.transform as trn

device = torch.device("cuda")

# %%
model_path = "best_model"
best_model = torch.load(model_path, map_location=device)

# %%
molecule_path = 'tob14.xyz'
ase_dir = './'
model_path = "best_model"

tob9_ase = spk.interfaces.AseInterface(
    molecule_path,
    ase_dir,
    model_file=model_path,
    neighbor_list=trn.ASENeighborList(cutoff=4.0),
    energy_key=MD17.energy,
    force_key=MD17.forces,
    energy_unit="eV",
    position_unit="Ang",
    device="cuda",
    dtype=torch.float64,
)
# Out:
# INFO:schnetpack.interfaces.ase_interface:Loading model from best_model

# %%
tob9_ase.optimize(fmax=1e-2)
# Out:
#                 Step[ FC]     Time          Energy          fmax
# BFGSLineSearch:    0[  0] 01:15:03     -655.486297        6.8985
# BFGSLineSearch:    1[  2] 01:15:04     -658.238317        3.9839
# BFGSLineSearch:    2[  4] 01:15:05     -659.778819        2.0739
# BFGSLineSearch:    3[  6] 01:15:06     -660.659885        1.5777
# BFGSLineSearch:    4[  8] 01:15:06     -661.197302        1.5864
# BFGSLineSearch:    5[ 10] 01:15:07     -661.756057        1.9080
# BFGSLineSearch:    6[ 12] 01:15:08     -662.168631        1.1695
# BFGSLineSearch:    7[ 14] 01:15:09     -662.535206        1.8203
# BFGSLineSearch:    8[ 16] 01:15:10     -662.792067        1.0102
# BFGSLineSearch:    9[ 18] 01:15:10     -662.965780        1.2853
# BFGSLineSearch:   10[ 20] 01:15:11     -663.181843        0.7461
# BFGSLineSearch:   11[ 22] 01:15:12     -663.309981        0.5625
# BFGSLineSearch:   12[ 24] 01:15:13     -663.410499        0.4290
# BFGSLineSearch:   13[ 26] 01:15:14     -663.508841        0.6988
# BFGSLineSearch:   14[ 28] 01:15:15     -663.625282        0.5602
# BFGSLineSearch:   15[ 30] 01:15:15     -663.674767        0.7344
# BFGSLineSearch:   16[ 32] 01:15:16     -663.769623        0.6502
# BFGSLineSearch:   17[ 34] 01:15:16     -663.834641        0.7293
# BFGSLineSearch:   18[ 36] 01:15:17     -663.900268        0.5960
# BFGSLineSearch:   19[ 38] 01:15:18     -663.971229        0.6685
# BFGSLineSearch:   20[ 40] 01:15:18     -664.031621        0.7102
# BFGSLineSearch:   21[ 42] 01:15:19     -664.103783        0.3997
# BFGSLineSearch:   22[ 44] 01:15:20     -664.148796        0.4394
# BFGSLineSearch:   23[ 46] 01:15:20     -664.210428        0.5287
# BFGSLineSearch:   24[ 48] 01:15:21     -664.248304        0.3680
# BFGSLineSearch:   25[ 50] 01:15:22     -664.289703        0.4035
# BFGSLineSearch:   26[ 52] 01:15:23     -664.324847        0.3635
# BFGSLineSearch:   27[ 54] 01:15:23     -664.362430        0.3365
# BFGSLineSearch:   28[ 56] 01:15:24     -664.389736        0.3651
# BFGSLineSearch:   29[ 58] 01:15:25     -664.423361        0.3754
# BFGSLineSearch:   30[ 60] 01:15:25     -664.465903        0.3242
# BFGSLineSearch:   31[ 62] 01:15:26     -664.492918        0.3640
# BFGSLineSearch:   32[ 64] 01:15:27     -664.533997        0.5028
# BFGSLineSearch:   33[ 66] 01:15:27     -664.571257        0.3364
# BFGSLineSearch:  171[307] 01:16:58     -665.263302        0.3665
# BFGSLineSearch:  172[308] 01:16:58     -665.265673        0.2160
# BFGSLineSearch:  173[309] 01:16:59     -665.273916        0.1528
# BFGSLineSearch:  174[311] 01:17:00     -665.278201        0.3438
# BFGSLineSearch:  175[312] 01:17:00     -665.281883        0.0963
# BFGSLineSearch:  176[313] 01:17:01     -665.285000        0.1335
# BFGSLineSearch:  177[314] 01:17:01     -665.287685        0.0885
# BFGSLineSearch:  178[315] 01:17:02     -665.288937        0.1221
# BFGSLineSearch:  179[316] 01:17:03     -665.289981        0.0377
# BFGSLineSearch:  180[317] 01:17:03     -665.290914        0.0385
# BFGSLineSearch:  181[318] 01:17:04     -665.291702        0.0299
# BFGSLineSearch:  182[319] 01:17:05     -665.292415        0.0281
# BFGSLineSearch:  183[320] 01:17:05     -665.292907        0.0506
# BFGSLineSearch:  184[321] 01:17:06     -665.293337        0.0326
# BFGSLineSearch:  185[322] 01:17:07     -665.293730        0.0315
# BFGSLineSearch:  186[323] 01:17:07     -665.294156        0.0386
# BFGSLineSearch:  187[324] 01:17:08     -665.294537        0.0297
# BFGSLineSearch:  188[325] 01:17:08     -665.294972        0.0404
# BFGSLineSearch:  189[326] 01:17:09     -665.295366        0.0250
# BFGSLineSearch:  190[327] 01:17:10     -665.295735        0.0247
# BFGSLineSearch:  191[328] 01:17:10     -665.296051        0.0168
# BFGSLineSearch:  192[329] 01:17:11     -665.296326        0.0170
# BFGSLineSearch:  193[330] 01:17:12     -665.296551        0.0175
# BFGSLineSearch:  194[331] 01:17:12     -665.296736        0.0132
# BFGSLineSearch:  195[332] 01:17:13     -665.296879        0.0215
# BFGSLineSearch:  196[333] 01:17:13     -665.296987        0.0140
# BFGSLineSearch:  197[334] 01:17:14     -665.297067        0.0166
# BFGSLineSearch:  198[335] 01:17:15     -665.297127        0.0103
# BFGSLineSearch:  199[336] 01:17:15     -665.297174        0.0076
# /home/zkm/.local/lib/python3.8/site-packages/ase/io/extxyz.py:1000: UserWarning: write_xyz() overwriting array "forces" present in atoms.arrays with stored results from calculator
#   warnings.warn('write_xyz() overwriting array "{0}" present '

# %%
molecule_path = 'optimization.extxyz'
ase_dir = './'
model_path = "best_model"

tob9_op_ase = spk.interfaces.AseInterface(
    molecule_path,
    ase_dir,
    model_file=model_path,
    neighbor_list=trn.ASENeighborList(cutoff=4.0),
    energy_key=MD17.energy,
    force_key=MD17.forces,
    energy_unit="eV",
    position_unit="Ang",
    device="cuda",
    dtype=torch.float64,
)

# !rm './simulation_300K.log'
# !rm './simulation_300K.traj'

tob9_op_ase.init_md(
    'simulation_300K',
    time_step=0.5, #fs
    temp_init=300,
    temp_bath=300, #NVT None:NVE
    reset=True,
    interval=100
)

tob9_ase.run_md(1000000)
# Out:
# INFO:schnetpack.interfaces.ase_interface:Loading model from best_model
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 30
#      19 get_ipython().system("rm './simulation_300K.traj'")
#      21 tob9_ase.init_md(
#      22     'simulation_300K',
#      23     time_step=0.5, #fs
#    (...)
#      27     interval=100
#      28 )
# ---> 30 tob9_ase.run_md(1000000)
#
# File ~/anaconda3/envs/schnet/lib/python3.8/site-packages/schnetpack/interfaces/ase_interface.py:534, in AseInterface.run_md(self, steps)
#     529 if not self.dynamics:
#     530     raise AttributeError(
#     531         "Dynamics need to be initialized using the" " 'setup_md' function"
#     532     )
# --> 534 self.dynamics.run(steps)
#
# File ~/.local/lib/python3.8/site-packages/ase/md/md.py:137, in MolecularDynamics.run(self, steps)
#     135 """ Call Dynamics.run and adjust max_steps """
#     136 self.max_steps = steps + self.nsteps
# --> 137 return Dynamics.run(self)
#
# File ~/.local/lib/python3.8/site-packages/ase/optimize/optimize.py:156, in Dynamics.run(self)
#     149 def run(self):
#     150     """Run dynamics algorithm.
#     151
#     152     This method will return when the forces on all individual
#     153     atoms are less than *fmax* or when the number of steps exceeds
#     154     *steps*."""
# --> 156     for converged in Dynamics.irun(self):
#     157         pass
#     158     return converged
#
# File ~/.local/lib/python3.8/site-packages/ase/optimize/optimize.py:135, in Dynamics.irun(self)
#     131 # run the algorithm until converged or max_steps reached
#     132 while not self.converged() and self.nsteps < self.max_steps:
#     133
#     134     # compute the next step
# --> 135     self.step()
#     136     self.nsteps += 1
#     138     # let the user inspect the step and change things before logging
#     139     # and predicting the next step
#
# File ~/.local/lib/python3.8/site-packages/ase/md/langevin.py:171, in Langevin.step(self, forces)
#     168 # recalc velocities after RATTLE constraints are applied
#     169 self.v = (self.atoms.get_positions() - x -
#     170           self.c5 * self.eta) / self.dt
# --> 171 forces = atoms.get_forces(md=True)
#     173 # Update the velocities
#     174 self.v += (self.c1 * forces / self.masses - self.c2 * self.v +
#     175            self.c3 * self.xi - self.c4 * self.eta)
#
# File ~/.local/lib/python3.8/site-packages/ase/atoms.py:788, in Atoms.get_forces(self, apply_constraint, md)
#     786 if self._calc is None:
#     787     raise RuntimeError('Atoms object has no calculator.')
# --> 788 forces = self._calc.get_forces(self)
#     790 if apply_constraint:
#     791     # We need a special md flag here because for MD we want
#     792     # to skip real constraints but include special "constraints"
#     793     # Like Hookean.
#     794     for constraint in self.constraints:
#
# File ~/.local/lib/python3.8/site-packages/ase/calculators/abc.py:23, in GetPropertiesMixin.get_forces(self, atoms)
#      22 def get_forces(self, atoms=None):
# ---> 23     return self.get_property('forces', atoms)
#
# File ~/.local/lib/python3.8/site-packages/ase/calculators/calculator.py:737, in Calculator.get_property(self, name, atoms, allow_calculation)
#     735     if not allow_calculation:
#     736         return None
# --> 737     self.calculate(atoms, [name], system_changes)
#     739 if name not in self.results:
#     740     # For some reason the calculator was not able to do what we want,
#     741     # and that is OK.
#     742     raise PropertyNotImplementedError('{} not present in this '
#     743                                       'calculation'.format(name))
#
# File ~/anaconda3/envs/schnet/lib/python3.8/site-packages/schnetpack/interfaces/ase_interface.py:294, in SpkCalculator.calculate(self, atoms, properties, system_changes)
#     292 # Convert to schnetpack input format
#     293 model_inputs = self.converter(atoms)
# --> 294 model_results = self.model(model_inputs)
#     296 results = {}
#     297 # TODO: use index information to slice everything properly
#
# File ~/anaconda3/envs/schnet/lib/python3.8/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/schnet/lib/python3.8/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/anaconda3/envs/schnet/lib/python3.8/site-packages/schnetpack/model/base.py:182, in NeuralNetworkPotential.forward(self, inputs)
#     179 inputs = self.representation(inputs)
#     181 for m in self.output_modules:
# --> 182     inputs = m(inputs)
#     184 # apply postprocessing (if enabled)
#     185 inputs = self.postprocess(inputs)
#
# File ~/anaconda3/envs/schnet/lib/python3.8/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/schnet/lib/python3.8/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/anaconda3/envs/schnet/lib/python3.8/site-packages/schnetpack/atomistic/atomwise.py:80, in Atomwise.forward(self, inputs)
#      78 if self.aggregation_mode is not None:
#      79     idx_m = inputs[properties.idx_m]
# ---> 80     maxm = int(idx_m[-1]) + 1
#      81     y = snn.scatter_add(y, idx_m, dim_size=maxm)
#      82     y = torch.squeeze(y, -1)
#
# KeyboardInterrupt:
