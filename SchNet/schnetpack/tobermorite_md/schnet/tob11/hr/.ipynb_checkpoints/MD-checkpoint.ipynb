# %%
from ase import Atoms, io
import torch
import schnetpack as spk
from schnetpack.data import AtomsDataModule
from schnetpack.datasets import MD17
import schnetpack.transform as trn

device = torch.device("cuda")

# %%
model_path = "best_model"
best_model = torch.load(model_path, map_location=device)

# %%
molecule_path = 'tob11.xyz'
ase_dir = './'
model_path = "best_model"

tob9_ase = spk.interfaces.AseInterface(
    molecule_path,
    ase_dir,
    model_file=model_path,
    neighbor_list=trn.ASENeighborList(cutoff=4.0),
    energy_key=MD17.energy,
    force_key=MD17.forces,
    energy_unit="eV",
    position_unit="Ang",
    device="cuda",
    dtype=torch.float64,
)
# Out:
# INFO:schnetpack.interfaces.ase_interface:Loading model from best_model

# %%
tob9_ase.optimize(fmax=1e-2)
# Out:
#                 Step[ FC]     Time          Energy          fmax
# BFGSLineSearch:    0[  0] 01:14:32     -570.848020        4.0005
# BFGSLineSearch:    1[  2] 01:14:32     -573.038387        2.2022
# BFGSLineSearch:    2[  4] 01:14:33     -574.135508        2.7074
# BFGSLineSearch:    3[  6] 01:14:34     -574.917681        1.1511
# BFGSLineSearch:    4[  8] 01:14:34     -575.287775        1.5068
# BFGSLineSearch:    5[ 10] 01:14:34     -575.760423        1.3880
# BFGSLineSearch:    6[ 12] 01:14:35     -576.096776        1.0063
# BFGSLineSearch:    7[ 14] 01:14:35     -576.371653        1.0067
# BFGSLineSearch:    8[ 16] 01:14:35     -576.543972        0.6621
# BFGSLineSearch:    9[ 18] 01:14:36     -576.700419        0.9718
# BFGSLineSearch:   10[ 20] 01:14:37     -576.838476        0.6578
# BFGSLineSearch:   11[ 22] 01:14:37     -576.954318        0.5551
# BFGSLineSearch:   12[ 24] 01:14:38     -577.068367        0.7043
# BFGSLineSearch:   13[ 26] 01:14:39     -577.144742        0.5870
# BFGSLineSearch:   14[ 28] 01:14:39     -577.231321        0.7378
# BFGSLineSearch:   15[ 30] 01:14:40     -577.296215        0.4309
# BFGSLineSearch:   16[ 32] 01:14:40     -577.369525        0.4981
# BFGSLineSearch:   17[ 34] 01:14:41     -577.417120        0.4506
# BFGSLineSearch:   18[ 36] 01:14:41     -577.467091        0.3370
# BFGSLineSearch:   19[ 38] 01:14:42     -577.488696        0.2608
# BFGSLineSearch:   20[ 40] 01:14:43     -577.522228        0.3907
# BFGSLineSearch:   21[ 42] 01:14:43     -577.541937        0.1857
# BFGSLineSearch:   22[ 44] 01:14:44     -577.554373        0.2311
# BFGSLineSearch:   23[ 46] 01:14:45     -577.571824        0.1944
# BFGSLineSearch:   24[ 48] 01:14:45     -577.580622        0.1627
# BFGSLineSearch:   25[ 50] 01:14:46     -577.589945        0.1891
# BFGSLineSearch:   26[ 52] 01:14:46     -577.598399        0.1924
# BFGSLineSearch:   27[ 54] 01:14:47     -577.607131        0.2158
# BFGSLineSearch:   28[ 56] 01:14:48     -577.612329        0.1352
# BFGSLineSearch:   29[ 58] 01:14:48     -577.619856        0.1624
# BFGSLineSearch:   30[ 60] 01:14:49     -577.625501        0.2110
# BFGSLineSearch:   31[ 62] 01:14:50     -577.634025        0.2340
# BFGSLineSearch:   32[ 64] 01:14:50     -577.638511        0.1743
# BFGSLineSearch:   33[ 66] 01:14:51     -577.645300        0.1614
site-packages/ase/io/extxyz.py:1000: UserWarning: write_xyz() overwriting array "forces" present in atoms.arrays with stored results from calculator
#   warnings.warn('write_xyz() overwriting array "{0}" present '

# %%
molecule_path = 'optimization.extxyz'
ase_dir = './'
model_path = "best_model"

tob9_op_ase = spk.interfaces.AseInterface(
    molecule_path,
    ase_dir,
    model_file=model_path,
    neighbor_list=trn.ASENeighborList(cutoff=4.0),
    energy_key=MD17.energy,
    force_key=MD17.forces,
    energy_unit="eV",
    position_unit="Ang",
    device="cuda",
    dtype=torch.float64,
)

# !rm './simulation_300K.log'
# !rm './simulation_300K.traj'

tob9_op_ase.init_md(
    'simulation_300K',
    time_step=0.5, #fs
    temp_init=300,
    temp_bath=300, #NVT None:NVE
    reset=True,
    interval=100
)

tob9_op_ase.run_md(1000000)
# Out:
# INFO:schnetpack.interfaces.ase_interface:Loading model from best_model
# rm: cannot remove './simulation_300K.log': No such file or directory
# rm: cannot remove './simulation_300K.traj': No such file or directory
# /home/zkm/.local/lib/python3.8/site-packages/ase/md/md.py:48: FutureWarning: Specify the temperature in K using the 'temperature_K' argument
#   warnings.warn(FutureWarning(w))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 30
#      19 get_ipython().system("rm './simulation_300K.traj'")
#      21 tob9_op_ase.init_md(
#      22     'simulation_300K',
#      23     time_step=0.5, #fs
#    (...)
#      27     interval=100
#      28 )
# ---> 30 tob9_op_ase.run_md(1000000)
#
# File ~/anaconda3/envs/schnet/lib/python3.8/site-packages/schnetpack/interfaces/ase_interface.py:534, in AseInterface.run_md(self, steps)
#     529 if not self.dynamics:
#     530     raise AttributeError(
#     531         "Dynamics need to be initialized using the" " 'setup_md' function"
#     532     )
# --> 534 self.dynamics.run(steps)
#
# File ~/.local/lib/python3.8/site-packages/ase/md/md.py:137, in MolecularDynamics.run(self, steps)
#     135 """ Call Dynamics.run and adjust max_steps """
#     136 self.max_steps = steps + self.nsteps
# --> 137 return Dynamics.run(self)
#
# File ~/.local/lib/python3.8/site-packages/ase/optimize/optimize.py:156, in Dynamics.run(self)
#     149 def run(self):
#     150     """Run dynamics algorithm.
#     151
#     152     This method will return when the forces on all individual
#     153     atoms are less than *fmax* or when the number of steps exceeds
#     154     *steps*."""
# --> 156     for converged in Dynamics.irun(self):
#     157         pass
#     158     return converged
#
# File ~/.local/lib/python3.8/site-packages/ase/optimize/optimize.py:135, in Dynamics.irun(self)
#     131 # run the algorithm until converged or max_steps reached
#     132 while not self.converged() and self.nsteps < self.max_steps:
#     133
#     134     # compute the next step
# --> 135     self.step()
#     136     self.nsteps += 1
#     138     # let the user inspect the step and change things before logging
#     139     # and predicting the next step
#
# File ~/.local/lib/python3.8/site-packages/ase/md/langevin.py:171, in Langevin.step(self, forces)
#     168 # recalc velocities after RATTLE constraints are applied
#     169 self.v = (self.atoms.get_positions() - x -
#     170           self.c5 * self.eta) / self.dt
# --> 171 forces = atoms.get_forces(md=True)
#     173 # Update the velocities
#     174 self.v += (self.c1 * forces / self.masses - self.c2 * self.v +
#     175            self.c3 * self.xi - self.c4 * self.eta)
#
# File ~/.local/lib/python3.8/site-packages/ase/atoms.py:788, in Atoms.get_forces(self, apply_constraint, md)
#     786 if self._calc is None:
#     787     raise RuntimeError('Atoms object has no calculator.')
# --> 788 forces = self._calc.get_forces(self)
#     790 if apply_constraint:
#     791     # We need a special md flag here because for MD we want
#     792     # to skip real constraints but include special "constraints"
#     793     # Like Hookean.
#     794     for constraint in self.constraints:
#
# File ~/.local/lib/python3.8/site-packages/ase/calculators/abc.py:23, in GetPropertiesMixin.get_forces(self, atoms)
#      22 def get_forces(self, atoms=None):
# ---> 23     return self.get_property('forces', atoms)
#
# File ~/.local/lib/python3.8/site-packages/ase/calculators/calculator.py:737, in Calculator.get_property(self, name, atoms, allow_calculation)
#     735     if not allow_calculation:
#     736         return None
# --> 737     self.calculate(atoms, [name], system_changes)
#     739 if name not in self.results:
#     740     # For some reason the calculator was not able to do what we want,
#     741     # and that is OK.
#     742     raise PropertyNotImplementedError('{} not present in this '
#     743                                       'calculation'.format(name))
#
# File ~/anaconda3/envs/schnet/lib/python3.8/site-packages/schnetpack/interfaces/ase_interface.py:293, in SpkCalculator.calculate(self, atoms, properties, system_changes)
#     290 Calculator.calculate(self, atoms)
#     292 # Convert to schnetpack input format
# --> 293 model_inputs = self.converter(atoms)
#     294 model_results = self.model(model_inputs)
#     296 results = {}
#
# File ~/anaconda3/envs/schnet/lib/python3.8/site-packages/schnetpack/interfaces/ase_interface.py:152, in AtomsConverter.__call__(self, atoms)
#     149     inputs.update(self.additional_inputs)
#     151     for transform in self.transforms:
# --> 152         inputs = transform(inputs)
#     153     inputs_batch.append(inputs)
#     155 inputs = _atoms_collate_fn(inputs_batch)
#
# File ~/anaconda3/envs/schnet/lib/python3.8/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/schnet/lib/python3.8/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/anaconda3/envs/schnet/lib/python3.8/site-packages/schnetpack/transform/neighborlist.py:185, in NeighborListTransform.forward(self, inputs)
#     182 cell = inputs[properties.cell].view(3, 3)
#     183 pbc = inputs[properties.pbc]
# --> 185 idx_i, idx_j, offset = self._build_neighbor_list(Z, R, cell, pbc, self._cutoff)
#     186 inputs[properties.idx_i] = idx_i.detach()
#     187 inputs[properties.idx_j] = idx_j.detach()
#
# File ~/anaconda3/envs/schnet/lib/python3.8/site-packages/schnetpack/transform/neighborlist.py:211, in ASENeighborList._build_neighbor_list(self, Z, positions, cell, pbc, cutoff)
#     208 def _build_neighbor_list(self, Z, positions, cell, pbc, cutoff):
#     209     at = Atoms(numbers=Z, positions=positions, cell=cell, pbc=pbc)
# --> 211     idx_i, idx_j, S = ase_neighbor_list("ijS", at, cutoff, self_interaction=False)
#     212     idx_i = torch.from_numpy(idx_i)
#     213     idx_j = torch.from_numpy(idx_j)
#
# File ~/.local/lib/python3.8/site-packages/ase/neighborlist.py:619, in neighbor_list(quantities, a, cutoff, self_interaction, max_nbins)
#     512 def neighbor_list(quantities, a, cutoff, self_interaction=False,
#     513                   max_nbins=1e6):
#     514     """Compute a neighbor list for an atomic configuration.
#     515
#     516     Atoms outside periodic boundaries are mapped into the box. Atoms
#    (...)
#     617
#     618     """
# --> 619     return primitive_neighbor_list(quantities, a.pbc,
#     620                                    a.get_cell(complete=True),
#     621                                    a.positions, cutoff, numbers=a.numbers,
#     622                                    self_interaction=self_interaction,
#     623                                    max_nbins=max_nbins)
#
# File ~/.local/lib/python3.8/site-packages/ase/neighborlist.py:414, in primitive_neighbor_list(quantities, pbc, cell, positions, cutoff, numbers, self_interaction, use_scaled_positions, max_nbins)
#     412     first_at_neightuple_n = first_at_neightuple_n[m]
#     413     secnd_at_neightuple_n = secnd_at_neightuple_n[m]
# --> 414     cell_shift_vector_n = cell_shift_vector_n[m]
#     416 # For nonperiodic directions, remove any bonds that cross the domain
#     417 # boundary.
#     418 for c in range(3):
#
# KeyboardInterrupt:
